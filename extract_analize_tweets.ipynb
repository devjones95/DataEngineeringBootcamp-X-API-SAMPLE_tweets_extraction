# %%
# !pip install tweepy datetime
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json

# %%
# !python get_tweets.py
# Out:
# Traceback (most recent call last):
#   File "c:\Users\JoãoPedroAssis\OneDrive - Lima Consulting Group LLC\Documentos\Data Engineering\API Twitter\get_tweets.py", line 42, in <module>
#     rules = stream.get_rules()
#   File "c:\Users\JoãoPedroAssis\AppData\Local\Programs\Python\Python314\Lib\site-packages\tweepy\streaming.py", line 480, in get_rules
#     return self._make_request(
#            ~~~~~~~~~~~~~~~~~~^
#         "GET", f"/2/tweets/search/stream/rules", params=params,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         endpoint_parameters=("ids",), data_type=StreamRule
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\JoãoPedroAssis\AppData\Local\Programs\Python\Python314\Lib\site-packages\tweepy\client.py", line 129, in _make_request
#     response = self.request(method, route, params=request_params,
#                             json=json, user_auth=user_auth)
# ...
